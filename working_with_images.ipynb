# %% [markdown]
# <a href="https://colab.research.google.com/github/andreeo/computer-vision/blob/main/working_with_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Image Formats
# OpenCV can read many different image formats like JPG, PNG, etc. JPG  is  probably the most  common  format.
#
# JPEG
#
# 1.   Most popular
# 2.   Lost image format
# 3.   Small filesize
#
# VS
#
# PNG
#
# 1.   Very popular
# 2.   Lossless & possy options
# 3.   Supports transparency

# %% [markdown]
# #Images
#
# We will cover the following:
#
# 1. Image I/O - Read, Write & Display an image
# 2. Image Properties - color, channels, shape, image structure
# 3. Creating new images, accessing pixels and ROI(Region of  Interest)

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip -qq drive/MyDrive/opencv-data/week1_python.zip  -d  /content/week1_python
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# mapname:  conversion of  failed
# replace /content/week1_python/README_Week1.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# #Import libraries

# %%
#import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize']  = (6.0, 6.0)
matplotlib.rcParams['image.cmap']  = 'gray'

# %%
imagePath = "/content/week1_python/data/images"

# %% [markdown]
# #Read an Image
#
# check here the  [im read](https://docs.opencv.org/4.x/d4/da8/group__imgcodecs.html#ga288b8b3da0892bd651fce07b3bbd3a56) function

# %%
#read image in grayscale format
testImage = imagePath + "/number_zero.jpg"
readImage = cv2.imread(testImage, cv2.IMREAD_GRAYSCALE)
print(readImage)
# Out:
# [[  1   0   3   0   3   0   3   2   4   2   0]
#  [  0   1   0   3   3 253 253   0   0   2   1]
#  [  0   0   8   0 249 255 255 253  71   1   5]
#  [  3   0   2 251 255   2   0 253 254   0   2]
#  [  1   5   0 252   4   0   3   0 255   4   0]
#  [  0   0   2 255   0   0   0   3 253   0   4]
#  [  0   5   4 249   4   2   0   0 255   1   0]
#  [  2   0   0 255   3   0   5   0 254   0   4]
#  [  0   0   0 255   1   0   0   3 255   0   0]
#  [  1   5   0 252   2   2   2  76 250   7   0]
#  [  0   0   5   0 254   0   0 255 254   0   1]
#  [  0   8   0   3 253 253 255 250   1   2   1]
#  [  2   0   0   0   5   0   4   1   3   0   0]]

# %% [markdown]
# #Intensity
#
# The values printed  abve are  the intensity values of each pixel.
# **0 means black pixel and as the value increases, it moves towards white. A value of  255 is white pixel**

# %% [markdown]
# #Images properties

# %%
print("Data type = {}\n".format(readImage.dtype))
print("Object type = {}\n".format(type(readImage)))
print("Image Dimensions  = {}\n".format(readImage.shape))
# Out:
# Data type = uint8
#
# Object type = <class 'numpy.ndarray'>
#
# Image Dimensions  = (13, 11)

# %% [markdown]
# The following observations can be made:
#
# 1. The **datatype** of the loaded image is **unsigned int and the depth is 8 bit**
# 2. The image is just a 2-dimensional array numpy array with the values ranging from **0 to 255**.
# 3. The size or resolution is 13x11 which means  **height=14** and **witdh=11**. In other words, it has  13 rows and  11 columns
#
#
# **NOTE:
# It should be kept in mind that in OpenCV, size is represented as a tuple of widthxheight or #columnsX#rows. But in numpy, the shape method returns size as a tuple of heightxwidth.**

# %% [markdown]
# # Manipulating pixels

# %%
#to access the first  element  we simply use  the following syntax
print(readImage[0,0])
# Out:
# 1

# %% [markdown]
# Note on indexing
#
# Since matrices are numpy arrays, the first index will be the row number and second index is column number. This leads to a lot of confusion since we think of pixels in terms of (x,y) or (column,row) coordinates and not (row,column)
#
# For example, to access the element at 4th row and 5th column, we should use img[3,4]. But as we will see in Image annotation section, we will deal with points which are represented as (x,y) and thus, the coordinates will be (4,3).

# %% [markdown]
# #Modifying pixel values

# %%
readImage[0,0]=200
print(readImage)
# Out:
# [[200   0   3   0   3   0   3   2   4   2   0]
#  [  0   1   0   3   3 253 253   0   0   2   1]
#  [  0   0   8   0 249 255 255 253  71   1   5]
#  [  3   0   2 251 255   2   0 253 254   0   2]
#  [  1   5   0 252   4   0   3   0 255   4   0]
#  [  0   0   2 255   0   0   0   3 253   0   4]
#  [  0   5   4 249   4   2   0   0 255   1   0]
#  [  2   0   0 255   3   0   5   0 254   0   4]
#  [  0   0   0 255   1   0   0   3 255   0   0]
#  [  1   5   0 252   2   2   2  76 250   7   0]
#  [  0   0   5   0 254   0   0 255 254   0   1]
#  [  0   8   0   3 253 253 255 250   1   2   1]
#  [  2   0   0   0   5   0   4   1   3   0   0]]

# %% [markdown]
# #Manipulating group of pixels
#
# It can be done using range based indexing available in python.

# %%
#access to values that we want manipulate (ROI -> Region  of Interest)
roi = readImage[0:2, 0:4]
print("Selected Region\n{}\n".format(roi))
# Out:
# Selected Region
# [[200   0   3   0]
#  [  0   1   0   3]]

# %% [markdown]
# #Modifying a region

# %%
readImage[0:2, 0:4]=111
print("Modifed Matrix\n{}\n".format(readImage))
# Out:
# Modifed Matrix
# [[111 111 111 111   3   0   3   2   4   2   0]
#  [111 111 111 111   3 253 253   0   0   2   1]
#  [  0   0   8   0 249 255 255 253  71   1   5]
#  [  3   0   2 251 255   2   0 253 254   0   2]
#  [  1   5   0 252   4   0   3   0 255   4   0]
#  [  0   0   2 255   0   0   0   3 253   0   4]
#  [  0   5   4 249   4   2   0   0 255   1   0]
#  [  2   0   0 255   3   0   5   0 254   0   4]
#  [  0   0   0 255   1   0   0   3 255   0   0]
#  [  1   5   0 252   2   2   2  76 250   7   0]
#  [  0   0   5   0 254   0   0 255 254   0   1]
#  [  0   8   0   3 253 253 255 250   1   2   1]
#  [  2   0   0   0   5   0   4   1   3   0   0]]

# %% [markdown]
# #Display an image

# %%
readImage[0:2,0:4]=0
plt.imshow(readImage)
plt.colorbar()

# %% [markdown]
# #Write the image to disk
#
# check  here  the [imwrite](https://docs.opencv.org/4.x/d4/da8/group__imgcodecs.html#gabbc7ef1aa2edfaa87772f1202d67e0ce) function

# %%
cv2.imwrite("image_saved_to_disk.jpg",readImage)
# Out:
# True

# %%
#check if the file was successfuly saved
# %ls  -l image_saved_to_disk.jpg
# Out:
# -rw-r--r-- 1 root root 585 Feb  2 20:45 image_saved_to_disk.jpg

# %% [markdown]
# #Color Images
# we will see how to load color images

# %%
elon = imagePath + "/musk.jpg"
img = cv2.imread(elon)
print("Image Dimension = {}".format(img.shape))
# Out:
# Image Dimension = (500, 600, 3)

# %% [markdown]
# There are few thing to note here:
#
#
# 1.   The image in this case has 3 dimensions.
# 2.   The third dimension indicates the number of channels in an image. For most
# images, this number is 3(namely R,G,B). In some cases, there may be an additional  channel (called alpha channel) which contains transparency information of the pixels.

# %% [markdown]
# #Image Channels
#
# As mentioned above, the color image consists of multiple channels. Each channel itself is a grayscale image. **The combination of intensity values of the three channels gives the color that is displayed on the screen**.
#
# Let us have a brief look at the  most  popular color space - the RGB color space.
#
# In OpenCV, the order of channels  R,G and B is reverse. i.e. In the image matrix, the Blue channel is indexed first, followed by the Green channel and finally the Red channel.

# %%
plt.imshow(img)

# %% [markdown]
# This happen because OpenCV uses BGR format by default whereas Matplotlib assumes the image to be in RGB format. This can be fixed either

# %%
#convert BGR to RGB colorspace
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(imgRGB)

# %% [markdown]
# Or

# %%
#It will reverse the order of the 3rd dimension i.e. channels
plt.imshow(img[:,:,::-1])

# %% [markdown]
# Let us access the 3 channels and display the gray scale images in each channel

# %%
#show the channels
plt.figure(figsize=[20,5])

plt.subplot(131);
plt.imshow(img[:,:,0]);
plt.title("Blue Channel");

plt.subplot(132);
plt.imshow(img[:,:,1]);
plt.title("Green Channel");

plt.subplot(133);
plt.imshow(img[:,:,2]);
plt.title("Red Channel");

# %% [markdown]
# Observation
# We had already mentioned that a white pixel means a high intensity value. If you look at the channels closely and compare them with the original image, you should be able to make out the following observations:
#
# 1. We can see in the original image that the background is blue in color. Thus, the blue channel is also having higher intensity values for the bakground, whereas the red channel is almost black for the background.
# 2. The face is reddish in color and thus, the red channel has very high values in the face region, while the other channels are a bit lower.
# 3. There is a greenish tint in the original image which is also reflected in the Green channel
#
# This kind of information extraction can be very useful if you want to build basic applications which take decisions based on color ( more so, using specific color channel )

# %% [markdown]
# #Splitting and Merning channels

# %%
#split the image into the B,G,R components
b,g,r = cv2.split(img)

plt.figure(figsize=[20,5])

plt.subplot(141);
plt.imshow(b);
plt.title("Blue Channel");

plt.subplot(142);
plt.imshow(g);
plt.title("Green Channel");

plt.subplot(143);
plt.imshow(r);
plt.title("Red Channel");

#merge the individual channels into BGR image
imgMerged  =  cv2.merge((b,g,r))
plt.subplot(144);
plt.imshow(imgMerged[:,:,::-1]);
plt.title("Merged Ouput");

# %% [markdown]
# #Manipulating Color Pixels

# %%
readImageToColor = cv2.imread(testImage, cv2.IMREAD_COLOR)
plt.imshow(readImageToColor);
plt.title("Original");
print("We can see  that intensity  value now  has 3 elements - one for each channel = {}\n".format(readImageToColor[0,0]))

#modify pixels
#
#Let us change the pixel at
#location [0,0] to Yellow ( It is a mixture of Red and Green )
#location [1,1] to Cyan ( It is a mixture of Blue and Green )
#location [2,2] to Magenta ( It is a mixture of Blue and Red )

plt.figure(figsize=[20,20])

readImageToColor[0,0] = (0,255,255)
plt.subplot(131);
plt.imshow(readImageToColor[:,:,::-1]);
plt.title("Yellow");

readImageToColor[1,1] = (255,255,0)
plt.subplot(132);
plt.imshow(readImageToColor[:,:,::-1]);
plt.title("Cyan");

readImageToColor[2,2] = (255,0,255)
plt.subplot(133);
plt.imshow(readImageToColor[:,:,::-1]);
plt.title("Magenta");


#modify ROI
plt.figure(figsize=[20,20])

readImageToColor[0:3,0:3] = (255,0,0)
readImageToColor[3:6,0:3] = (0,255,0)
readImageToColor[6:9,0:3] = (0,0,255)

plt.subplot(151);
plt.imshow(readImageToColor[:,:,::-1]);
plt.title("Modified ROI");
# Out:
# We can see  that intensity  value now  has 3 elements - one for each channel = [1 1 1]

# %% [markdown]
# # Images with Alpha Channel
#
# In images with an alpha channel, each pixel not only has a color value, but also has a numerical transparency value ( between 0 to 255) that defines what will happen when the pixel is placed over another pixel.
#
# There are 4 channels, i.e. 3 color channels and 1 alpha channel which indicates the transparency.

# %%
panther = imagePath +  "/panther.png"

imgPNG = cv2.imread(panther, cv2.IMREAD_UNCHANGED)
print("Image Dimension = {}".format(imgPNG.shape))
#first 3 channels will be combined to form BGR image
#Mask is the alpha channel of the original image
imgBGR = imgPNG[:,:,0:3]
imgMask = imgPNG[:,:,3]
plt.figure(figsize=[15,15])

plt.subplot(121);
plt.imshow(imgBGR[:,:,::-1]);
plt.title("Color channels");

plt.subplot(122);
plt.imshow(imgMask, cmap='gray');
plt.title("Mask channel");
# Out:
# Image Dimension = (608, 640, 4)

# %% [markdown]
# You can see the whiskers very clearly in the mask image. The alpha mask is basically a very accurate segmentation of the image. It is useful for creating overlays ( Augmented Reality type of applications ). If you don't have tha alpha mask, then you have to separate out the whiskers from the white background ( see original image above ) which can be very difficult.
